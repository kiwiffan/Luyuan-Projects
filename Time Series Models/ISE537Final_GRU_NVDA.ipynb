# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
import scipy.stats as stats
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.metrics import mean_squared_error
from pmdarima import auto_arima
from sklearn.preprocessing import MinMaxScaler
import statsmodels.api as sm
from keras.models import Sequential
from keras.layers import Dense, LSTM, GRU
from tensorflow.keras.regularizers import l2
import warnings
warnings.filterwarnings("ignore")
# Out:
# 2024-12-10 22:59:00.082439: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
tickers = ['JPM', 'NVDA']

for ticker in tickers:
    stock_data = yf.download(ticker, start='2018-12-31', end='2022-12-31')
    
    prices = np.array(stock_data.reset_index()['Close'])
    prices_diff = prices[1:] - prices[:-1]
    prices_log = np.log(prices)
    prices_log_diff = prices_log[1:] - prices_log[:-1]
    
    df = pd.DataFrame({
        'prices': prices,
        'prices_diff': np.append([np.nan], prices_diff), 
        'prices_log': prices_log,
        'prices_log_diff': np.append([np.nan], prices_log_diff)  
    })
    
    globals()[f'{ticker}'] = df
    

print(JPM.head())
print(NVDA.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#        prices  prices_diff  prices_log  prices_log_diff
# 0   97.620003          NaN    4.581082              NaN
# 1   99.309998     1.689995    4.598246         0.017164
# 2   97.110001    -2.199997    4.575844        -0.022402
# 3  100.690002     3.580002    4.612047         0.036202
# 4  100.760002     0.070000    4.612741         0.000695
#     prices  prices_diff  prices_log  prices_log_diff
# 0  3.33750          NaN    1.205222              NaN
# 1  3.40550      0.06800    1.225392         0.020170
# 2  3.19975     -0.20575    1.163073        -0.062319
# 3  3.40475      0.20500    1.225172         0.062099
# 4  3.58500      0.18025    1.276758         0.051587

# %%
for ticker in tickers:
    stock_data = yf.download(ticker, start='2022-12-31', end='2023-12-31')
    
    prices = np.array(stock_data.reset_index()['Close'])
    prices_diff = prices[1:] - prices[:-1]
    prices_log = np.log(prices)
    prices_log_diff = prices_log[1:] - prices_log[:-1]
    
    df = pd.DataFrame({
        'prices': prices,
        'prices_diff': np.append([np.nan], prices_diff), 
        'prices_log': prices_log,
        'prices_log_diff': np.append([np.nan], prices_log_diff)  
    })
    
    globals()[f'{ticker}_test'] = df

print(JPM_test.head())
print(NVDA_test.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#        prices  prices_diff  prices_log  prices_log_diff
# 0  135.119995          NaN    4.906163              NaN
# 1  136.380005     1.260010    4.915445         0.009282
# 2  135.350006    -1.029999    4.907864        -0.007581
# 3  137.940002     2.589996    4.926819         0.018955
# 4  137.369995    -0.570007    4.922678        -0.004141
#    prices  prices_diff  prices_log  prices_log_diff
# 0  14.315          NaN    2.661308              NaN
# 1  14.749     0.434000    2.691175         0.029867
# 2  14.265    -0.483999    2.657809        -0.033366
# 3  14.859     0.594000    2.698606         0.040797
# 4  15.628     0.769000    2.749064         0.050458

# %%
NVDA_df = pd.concat([NVDA, NVDA_test], axis=0, ignore_index=True)
data = NVDA_df.filter(['prices'])
data
# Out:
#          prices
# 0      3.337500
# 1      3.405500
# 2      3.199750
# 3      3.404750
# 4      3.585000
# ...         ...
# 1254  48.830002
# 1255  49.278999
# 1256  49.417000
# 1257  49.521999
# 1258  49.521999
#
# [1259 rows x 1 columns]

# %%
dataset = data.values

# %%
scaler = MinMaxScaler(feature_range=(0,1))
traindata = dataset[0:1009, :]
train_data = scaler.fit_transform(traindata)

x_train = []
y_train = []

for i in range(10, len(train_data)):
    x_train.append(train_data[i-10:i, 0])
    y_train.append(train_data[i, 0])
    if i<= 11:
        print(x_train)
        print(y_train)
        print()
        
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# Out:
# [array([0.00456485, 0.00681828, 0.        , 0.00679343, 0.01276667,
#        0.00980904, 0.01208733, 0.01428276, 0.01726524, 0.01859906])]
# [0.018126844082459667]
#
# [array([0.00456485, 0.00681828, 0.        , 0.00679343, 0.01276667,
#        0.00980904, 0.01208733, 0.01428276, 0.01726524, 0.01859906]), array([0.00681828, 0.        , 0.00679343, 0.01276667, 0.00980904,
#        0.01208733, 0.01428276, 0.01726524, 0.01859906, 0.01812684])]
# [0.018126844082459667, 0.017273518681176922]

# %%
model = Sequential()
model.add(GRU(256, return_sequences=True, input_shape=(x_train.shape[1], 1), kernel_regularizer=l2(l2=0.01)))
# model.add(GRU(128, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(GRU(64, return_sequences=True))
model.add(GRU(32, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')

history = model.fit(
    x_train, 
    y_train, 
    batch_size=16, 
    epochs=100, 
    validation_split=0.2
)
model.save('NVDA_GRU.keras')
# Out:
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0386 - val_loss: 0.0099
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0063 - val_loss: 0.0052
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0036 - val_loss: 0.0053
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0029 - val_loss: 0.0044
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0024 - val_loss: 0.0028
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0017 - val_loss: 0.0033
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0022 - val_loss: 0.0047
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0017 - val_loss: 0.0062
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0019 - val_loss: 0.0028
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0013 - val_loss: 0.0025
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.9857e-04 - val_loss: 0.0016
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0011 - val_loss: 0.0022
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0011 - val_loss: 0.0027
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0010 - val_loss: 0.0018
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.2858e-04 - val_loss: 0.0014
# Epoch 23/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.1010e-04 - val_loss: 0.0017
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.8882e-04 - val_loss: 0.0015
# Epoch 25/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.0757e-04 - val_loss: 0.0015
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 27/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.2092e-04 - val_loss: 0.0028
# Epoch 29/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 30/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 31/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.1548e-04 - val_loss: 0.0012
# Epoch 32/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.1669e-04 - val_loss: 0.0011
# Epoch 33/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.5083e-04 - val_loss: 0.0011
# Epoch 34/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.9631e-04 - val_loss: 0.0011
# Epoch 35/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.8541e-04 - val_loss: 0.0011
# Epoch 36/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 37/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.3365e-04 - val_loss: 0.0012
# Epoch 38/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.1564e-04 - val_loss: 0.0011
# Epoch 39/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.0395e-04 - val_loss: 0.0015
# Epoch 40/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.3066e-04 - val_loss: 9.4161e-04
# Epoch 41/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.7371e-04 - val_loss: 0.0011
# Epoch 42/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.0611e-04 - val_loss: 0.0010
# Epoch 43/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.7537e-04 - val_loss: 0.0013
# Epoch 44/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.5847e-04 - val_loss: 9.2339e-04
# Epoch 45/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.8159e-04 - val_loss: 9.2671e-04
# Epoch 46/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.0295e-04 - val_loss: 8.5171e-04
# Epoch 47/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.7469e-04 - val_loss: 8.3140e-04
# Epoch 48/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.0588e-04 - val_loss: 0.0012
# Epoch 49/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.3111e-04 - val_loss: 8.1393e-04
# Epoch 50/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.6726e-04 - val_loss: 8.0631e-04
# Epoch 51/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.0726e-04 - val_loss: 0.0012
# Epoch 52/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.2906e-04 - val_loss: 0.0010
# Epoch 53/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.5854e-04 - val_loss: 7.8392e-04
# Epoch 54/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.7055e-04 - val_loss: 8.1010e-04
# Epoch 55/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.2379e-04 - val_loss: 9.0394e-04
# Epoch 56/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.1362e-04 - val_loss: 9.5958e-04
# Epoch 57/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.1095e-04 - val_loss: 7.4259e-04
# Epoch 58/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.6483e-04 - val_loss: 8.6642e-04
# Epoch 59/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.8347e-04 - val_loss: 8.6270e-04
# Epoch 60/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.1808e-04 - val_loss: 9.8306e-04
# Epoch 61/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.2485e-04 - val_loss: 7.3074e-04
# Epoch 62/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.2525e-04 - val_loss: 0.0014
# Epoch 63/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.1849e-04 - val_loss: 7.5361e-04
# Epoch 64/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.4604e-04 - val_loss: 8.4828e-04
# Epoch 65/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.7290e-04 - val_loss: 8.9408e-04
# Epoch 66/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.6769e-04 - val_loss: 8.7180e-04
# Epoch 67/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.7694e-04 - val_loss: 7.6841e-04
# Epoch 68/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.5921e-04 - val_loss: 7.0316e-04
# Epoch 69/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.5632e-04 - val_loss: 7.6662e-04
# Epoch 70/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.0035e-04 - val_loss: 7.8358e-04
# Epoch 71/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.2698e-04 - val_loss: 7.4542e-04
# Epoch 72/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.9010e-04 - val_loss: 0.0012
# Epoch 73/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.6345e-04 - val_loss: 7.9466e-04
# Epoch 74/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.3278e-04 - val_loss: 7.2186e-04
# Epoch 75/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.2046e-04 - val_loss: 6.9460e-04
# Epoch 76/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.9946e-04 - val_loss: 0.0014
# Epoch 77/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.4317e-04 - val_loss: 0.0013
# Epoch 78/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.7450e-04 - val_loss: 6.9840e-04
# Epoch 79/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.8591e-04 - val_loss: 7.2135e-04
# Epoch 80/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.7415e-04 - val_loss: 6.8289e-04
# Epoch 81/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.9871e-04 - val_loss: 7.7231e-04
# Epoch 82/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.3343e-04 - val_loss: 7.3400e-04
# Epoch 83/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.5495e-04 - val_loss: 0.0022
# Epoch 84/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.2974e-04 - val_loss: 7.0075e-04
# Epoch 85/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.0342e-04 - val_loss: 7.5418e-04
# Epoch 86/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.2804e-04 - val_loss: 0.0012
# Epoch 87/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.6402e-04 - val_loss: 7.2040e-04
# Epoch 88/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.8875e-04 - val_loss: 6.9003e-04
# Epoch 89/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.4270e-04 - val_loss: 7.2655e-04
# Epoch 90/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.8074e-04 - val_loss: 8.2577e-04
# Epoch 91/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.5416e-04 - val_loss: 6.7170e-04
# Epoch 92/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.8804e-04 - val_loss: 6.6384e-04
# Epoch 93/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.8410e-04 - val_loss: 9.0926e-04
# Epoch 94/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.1025e-04 - val_loss: 6.9087e-04
# Epoch 95/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.2374e-04 - val_loss: 0.0011
# Epoch 96/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.8116e-04 - val_loss: 6.9971e-04
# Epoch 97/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.2853e-04 - val_loss: 9.3986e-04
# Epoch 98/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.5500e-04 - val_loss: 7.2284e-04
# Epoch 99/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.5473e-04 - val_loss: 8.9685e-04
# Epoch 100/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.7084e-04 - val_loss: 6.9387e-04

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
testdata = dataset[1009 - 10: , :]
test_data = scaler.transform(testdata)

x_test = []
y_test = dataset[1009:, :]

for i in range(10, len(test_data)):
    x_test.append(test_data[i-10:i, 0])
    
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))

predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
rmse
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step
# 1.0930318804932204

# %%
train = data[:1009]
valid = data[1009:]
valid['Predictions'] = predictions
plt.figure(figsize=(16,6))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['prices'][900:])
plt.plot(valid[['prices', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
